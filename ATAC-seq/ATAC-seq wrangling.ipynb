# %%
import pandas as pd
df = pd.read_csv("C:/Users/gusta/OneDrive/A MoBi/4. FS/Data Analysis/Fork 2/REAL_FORKED_abT-Tact-cells-Team2/raw datasets/ATAC-seq data.csv")
print("All columns")
print(df.columns)
# Out:
# All columns
# Index(['ImmGenATAC1219.peakID', 'chrom', 'Summit',
#        'mm10.60way.phastCons_scores', '_-log10_bestPvalue',
#        'Included.in.systematic.analysis', 'TSS', 'genes.within.100Kb',
#        'LTHSC.34-.BM', 'LTHSC.34+.BM', 'STHSC.150-.BM', 'MPP4.135+.BM',
#        'proB.CLP.BM', 'proB.FrA.BM', 'proB.FrBC.BM', 'preB.FrD.BM', 'B.FrE.BM',
#        'B1b.PC', 'B.T1.Sp', 'B.T2.Sp', 'B.T3.Sp', 'B.Sp', 'B.Fem.Sp',
#        'B.MZ.Sp', 'B.Fo.Sp', 'B.mem.Sp', 'B.GC.CB.Sp', 'B.GC.CC.Sp', 'B.PB.Sp',
#        'B.PC.Sp', 'B.PC.BM', 'preT.DN1.Th', 'preT.DN2a.Th', 'preT.DN2b.Th',
#        'preT.DN3.Th', 'T.DN4.Th', 'T.ISP.Th', 'T.DP.Th', 'T.4.Th', 'T.8.Th',
#        'T.4.Nve.Sp', 'T.4.Nve.Fem.Sp', 'T.8.Nve.Sp', 'T.4.Sp.aCD3+CD40.18hr',
#        'Treg.4.FP3+.Nrplo.Co', 'Treg.4.25hi.Sp', 'T8.TN.P14.Sp',
#        'T8.IEL.LCMV.d7.SI', 'T8.TE.LCMV.d7.Sp', 'T8.MP.LCMV.d7.Sp',
#        'T8.Tcm.LCMV.d180.Sp', 'T8.Tem.LCMV.d180.Sp', 'NKT.Sp',
#        'NKT.Sp.LPS.3hr', 'NKT.Sp.LPS.18hr', 'NKT.Sp.LPS.3d',
#        'Tgd.g2+d17.24a+.Th', 'Tgd.g2+d17.LN', 'Tgd.g2+d1.24a+.Th',
#        'Tgd.g2+d1.LN', 'Tgd.g1.1+d1.24a+.Th', 'Tgd.g1.1+d1.LN', 'Tgd.Sp',
#        'NK.27+11b-.BM', 'NK.27+11b+.BM', 'NK.27-11b+.BM', 'NK.27+11b-.Sp',
#        'NK.27+11b+.Sp', 'NK.27-11b+.Sp', 'ILC2.SI', 'ILC3.NKp46-CCR6-.SI',
#        'ILC3.NKp46+.SI', 'ILC3.CCR6+.SI', 'MPP3.48+.BM', 'GN.BM', 'GN.Sp',
#        'GN.Thio.PC', 'Mo.6C+II-.Bl', 'Mo.6C-II-.Bl', 'MF.pIC.Alv.Lu',
#        'MF.226+II+480lo.PC', 'MF.ICAM+480hi.PC', 'MF.RP.Sp', 'MF.LP.SI',
#        'MF.Alv.Lu', 'MF.microglia.CNS', 'MF.PC', 'MF.Fem.PC', 'DC.4+.Sp',
#        'DC.8+.Sp', 'DC.pDC.Sp', 'DC.103+11b+.SI', 'DC.103+11b-.SI', 'FRC.SLN',
#        'IAP.SLN', 'BEC.SLN', 'LEC.SLN', 'Ep.MEChi.Th'],
#       dtype='object')

# %%
meta_cols = df.columns[:8].tolist()

# select only relevant cells
cell_types_to_keep = [
    "preT.DN1.Th", "preT.DN2a.Th", "preT.DN2b.Th", "preT.DN3.Th",
    "T.DN4.Th", "T.ISP.Th", "T.DP.Th", "T.4.Th", "T.8.Th",
    "T.4.Nve.Sp", "T.4.Nve.Fem.Sp", "T.4.Sp.aCD3+CD40.18hr", "T.8.Nve.Sp",
    "Treg.4.25hi.Sp", "Treg.4.FP3+.Nrplo.Co",
    "T8.TN.P14.Sp", "T8.TE.LCMV.d7.Sp", "T8.MP.LCMV.d7.Sp", 
    "T8.IEL.LCMV.d7.SI",   
    "T8.Tcm.LCMV.d180.Sp", "T8.Tem.LCMV.d180.Sp",
    "NKT.Sp", "NKT.Sp.LPS.3hr", "NKT.Sp.LPS.18hr", "NKT.Sp.LPS.3d",
    "LTHSC.34-.BM", "LTHSC.34+.BM", "STHSC.150-.BM", "MPP4.135+.BM"
]

# subset including metadata to include peak IDs/chr/etc.
filtered_all_ATAC = df[ meta_cols + cell_types_to_keep ]

# save & check
filtered_all_ATAC.to_csv("filtered_ATAC_abT_Tact_Stem.csv", index=False)
print("Filtered shape:", filtered_all_ATAC.shape)
print("Columns kept:", filtered_all_ATAC.columns.tolist())
# Out:
# Filtered shape: (512595, 37)
# Columns kept: ['ImmGenATAC1219.peakID', 'chrom', 'Summit', 'mm10.60way.phastCons_scores', '_-log10_bestPvalue', 'Included.in.systematic.analysis', 'TSS', 'genes.within.100Kb', 'preT.DN1.Th', 'preT.DN2a.Th', 'preT.DN2b.Th', 'preT.DN3.Th', 'T.DN4.Th', 'T.ISP.Th', 'T.DP.Th', 'T.4.Th', 'T.8.Th', 'T.4.Nve.Sp', 'T.4.Nve.Fem.Sp', 'T.4.Sp.aCD3+CD40.18hr', 'T.8.Nve.Sp', 'Treg.4.25hi.Sp', 'Treg.4.FP3+.Nrplo.Co', 'T8.TN.P14.Sp', 'T8.TE.LCMV.d7.Sp', 'T8.MP.LCMV.d7.Sp', 'T8.IEL.LCMV.d7.SI', 'T8.Tcm.LCMV.d180.Sp', 'T8.Tem.LCMV.d180.Sp', 'NKT.Sp', 'NKT.Sp.LPS.3hr', 'NKT.Sp.LPS.18hr', 'NKT.Sp.LPS.3d', 'LTHSC.34-.BM', 'LTHSC.34+.BM', 'STHSC.150-.BM', 'MPP4.135+.BM']

# %%
# show as table

filtered_all_ATAC.head()
# Out:
#    ImmGenATAC1219.peakID chrom   Summit  mm10.60way.phastCons_scores  \
# 0  ImmGenATAC1219.peak_1  chr1  3020786                         0.00
# 1  ImmGenATAC1219.peak_2  chr1  3087226                         0.00
# 2  ImmGenATAC1219.peak_3  chr1  3120109                         0.07
# 3  ImmGenATAC1219.peak_4  chr1  3121485                         0.15
# 4  ImmGenATAC1219.peak_5  chr1  3372787                         0.03
#
#    _-log10_bestPvalue  Included.in.systematic.analysis  TSS  \
# 0                0.56                              NaN  NaN
# 1                0.50                              NaN  NaN
# 2               10.80                              1.0  NaN
# 3                3.02                              1.0  NaN
# 4                1.31                              NaN  NaN
#
#   genes.within.100Kb  preT.DN1.Th  preT.DN2a.Th  ...  T8.Tcm.LCMV.d180.Sp  \
# 0                NaN         0.11          0.77  ...                 0.71
# 1                NaN         0.77          0.77  ...                 0.94
# 2                NaN         0.40          0.77  ...                 1.32
# 3                NaN         0.46          0.11  ...                 3.41
# 4                NaN         0.77          0.84  ...                 0.94
#
#    T8.Tem.LCMV.d180.Sp  NKT.Sp  NKT.Sp.LPS.3hr  NKT.Sp.LPS.18hr  \
# 0                 2.78    0.56            0.11             0.64
# 1                 3.56    0.98            2.12             0.12
# 2                 2.79    0.56            1.72             0.12
# 3                 0.11    2.86            0.11             0.64
# 4                 0.11    1.59            0.51             0.12
#
#    NKT.Sp.LPS.3d  LTHSC.34-.BM  LTHSC.34+.BM  STHSC.150-.BM  MPP4.135+.BM
# 0           1.14          0.41          0.71           0.90          0.11
# 1           0.11          0.41          1.64           0.90          0.83
# 2           0.11          2.36          0.10           0.90          0.11
# 3           2.20          0.41          0.10           0.11          0.11
# 4           0.53          0.41          0.10           0.11          0.11
#
# [5 rows x 37 columns]

# %%
# melt subset so that each row is one peak-sample pair with SampleID and its corresponding singnal
# it's easier for later analysis

tidy = filtered_all_ATAC.melt(
    id_vars=meta_cols,
    value_vars=filtered_all_ATAC,
    var_name="Sample ID",
    value_name="Signal",
)
tidy.head()
# Out:
#    ImmGenATAC1219.peakID chrom   Summit  mm10.60way.phastCons_scores  \
# 0  ImmGenATAC1219.peak_1  chr1  3020786                         0.00
# 1  ImmGenATAC1219.peak_2  chr1  3087226                         0.00
# 2  ImmGenATAC1219.peak_3  chr1  3120109                         0.07
# 3  ImmGenATAC1219.peak_4  chr1  3121485                         0.15
# 4  ImmGenATAC1219.peak_5  chr1  3372787                         0.03
#
#    _-log10_bestPvalue  Included.in.systematic.analysis  TSS  \
# 0                0.56                              NaN  NaN
# 1                0.50                              NaN  NaN
# 2               10.80                              1.0  NaN
# 3                3.02                              1.0  NaN
# 4                1.31                              NaN  NaN
#
#   genes.within.100Kb    Sample ID  Signal
# 0                NaN  preT.DN1.Th    0.11
# 1                NaN  preT.DN1.Th    0.77
# 2                NaN  preT.DN1.Th    0.40
# 3                NaN  preT.DN1.Th    0.46
# 4                NaN  preT.DN1.Th    0.77

# %%
# export for further analysis

tidy.to_csv( "refined_ATAC.csv", index=False)
print( "Tidy ATAC shape:", tidy.shape)
print(tidy.head())
# Out:
# Tidy ATAC shape: (14865255, 10)
#    ImmGenATAC1219.peakID chrom   Summit  mm10.60way.phastCons_scores  \
# 0  ImmGenATAC1219.peak_1  chr1  3020786                         0.00
# 1  ImmGenATAC1219.peak_2  chr1  3087226                         0.00
# 2  ImmGenATAC1219.peak_3  chr1  3120109                         0.07
# 3  ImmGenATAC1219.peak_4  chr1  3121485                         0.15
# 4  ImmGenATAC1219.peak_5  chr1  3372787                         0.03
#
#    _-log10_bestPvalue  Included.in.systematic.analysis  TSS  \
# 0                0.56                              NaN  NaN
# 1                0.50                              NaN  NaN
# 2               10.80                              1.0  NaN
# 3                3.02                              1.0  NaN
# 4                1.31                              NaN  NaN
#
#   genes.within.100Kb    Sample ID  Signal
# 0                NaN  preT.DN1.Th    0.11
# 1                NaN  preT.DN1.Th    0.77
# 2                NaN  preT.DN1.Th    0.40
# 3                NaN  preT.DN1.Th    0.46
# 4                NaN  preT.DN1.Th    0.77

# %% [markdown]
# # Filtering out low variance peaks
#
# Peaks with low variance represent chromatin landscape regions with low variation across cell types. These can be left out of our further analysis as they give us little input to differing regulatory landscapes between cell lines.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Converting signal columns to float32 for memory efficiency
filtered_all_ATAC = filtered_all_ATAC.copy()
filtered_all_ATAC.loc[:, cell_types_to_keep] = filtered_all_ATAC[cell_types_to_keep].astype('float32')
filtered_all_ATAC.loc[:, 'variance'] = filtered_all_ATAC[cell_types_to_keep].var(axis=1)


# Computing per-peak variance across the selected cell types
sample_cols = cell_types_to_keep
filtered_all_ATAC['variance'] = filtered_all_ATAC[sample_cols].var(axis=1)

# Inspecting the distribution of variances to choose a cutoff

plt.hist(filtered_all_ATAC['variance'], bins=100)
plt.xlabel('Peak variance across cell types')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Using log-scaling as the previous graph is pretty stacked up.

# %%
# Added a small constant so zeros don’t turn into –∞
x = np.log10(filtered_all_ATAC['variance'] + 1e-3)

plt.figure()
plt.hist(x, bins=100)
plt.xlabel('log10(variance + 1e-3)')
plt.ylabel('Frequency')
plt.title('Distribution of log-transformed peak variances')
plt.show()

# %% [markdown]
# Method chosen for finding a cutoff for filtering out low variance peaks. This was the most meaningful one.
#
# - MAD (median absolute deviation) flags peaks whose log-variance is more than 2× the median absolute deviation above the median.

# %%
import numpy as np
import pandas as pd

filtered_all_ATAC = pd.read_csv("filtered_ATAC_abT_Tact_Stem.csv")

# Make sure 'variance' exists:
if 'variance' not in filtered_all_ATAC:
    meta_cols   = filtered_all_ATAC.columns[:8].tolist()
    sample_cols = [c for c in filtered_all_ATAC.columns if c not in meta_cols]
    # cast to float32 to save memory
    filtered_all_ATAC[sample_cols] = filtered_all_ATAC[sample_cols].astype('float32')
    filtered_all_ATAC['variance'] = filtered_all_ATAC[sample_cols].var(axis=1)

# Compute the MAD-based cutoff (k=2)
logv      = np.log10(filtered_all_ATAC['variance'] + 1e-6)
med       = np.median(logv)
mad       = np.median(np.abs(logv - med))
k         = 2
cut_log   = med + k * mad
cut_var   = 10 ** cut_log

print(f"MAD variance cutoff: {cut_var:.3f} (log10 = {cut_log:.3f})")

# Subset
high_var = filtered_all_ATAC[filtered_all_ATAC['variance'] > cut_var].copy()

print(f"Retained {len(high_var)} / {len(filtered_all_ATAC)} peaks "
      f"({len(high_var)/len(filtered_all_ATAC)*100:.1f}%)")
# Out:
# MAD variance cutoff: 10.176 (log10 = 1.008)
# Retained 96960 / 512595 peaks (18.9%)

# %% [markdown]
# # Hexbin Plot
#
# Using a hexbin plot can be helpful to analyze how variance and another metric correlate. By doing so we can have an even more meaningful and sensible cutoff for the ATAC peaks.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,5))
hb = plt.hexbin(
    filtered_all_ATAC['_-log10_bestPvalue'],
    filtered_all_ATAC['variance'],
    gridsize=60,
    yscale='log',
    mincnt=1
)
plt.colorbar(hb, label='Count of peaks')
plt.xlabel('-log10(best P-value)')
plt.ylabel('Variance (per peak)')
plt.title('Hexbin: Variance vs. –log10(best P-value)')
plt.show()

# %% [markdown]
# This plot shows us that there are high variance peaks with low significance/confidence scores. Might also be useful to filter these out.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Recompute MAD-based cutoffs ---
# log-variance
log_v = np.log10(filtered_all_ATAC['variance'] + 1e-6)
med_v = np.median(log_v)
mad_v = np.median(np.abs(log_v - med_v))
k     = 2
cut_v_log   = med_v + k * mad_v
cut_var_mad = 10 ** cut_v_log

# -log10 P-value
lp    = filtered_all_ATAC['_-log10_bestPvalue'].values
med_lp = np.median(lp)
mad_lp = np.median(np.abs(lp - med_lp))
cut_lp = med_lp + k * mad_lp

print(f"Variance cutoff = {cut_var_mad:.3f} (log10 = {cut_v_log:.3f})")
print(f"-log10P cutoff  = {cut_lp:.3f}")

# Plot hexbin with threshold lines
plt.figure(figsize=(6,5))
hb = plt.hexbin(
    filtered_all_ATAC['_-log10_bestPvalue'],
    filtered_all_ATAC['variance'],
    gridsize=60,
    yscale='log',
    mincnt=1,
    cmap='viridis'
)
plt.colorbar(hb, label='Peak count')

# vertical line for -log10P threshold
plt.axvline(cut_lp, color='red', linestyle='--', linewidth=1, label=f"-log10P > {cut_lp:.1f}")
# horizontal line for variance threshold
plt.axhline(cut_var_mad, color='orange', linestyle='--', linewidth=1, label=f"variance > {cut_var_mad:.1f}")

plt.xlabel('-log10(best P-value)')
plt.ylabel('Variance')
plt.title('Variance vs. –log10P with MAD thresholds')
plt.legend(frameon=False)
plt.tight_layout()
plt.show()

# Subset peaks passing both criteria
high_var_sig = filtered_all_ATAC[
    (filtered_all_ATAC['variance']   > cut_var_mad) &
    (filtered_all_ATAC['_-log10_bestPvalue'] > cut_lp)
].copy()

# Save to CSV
high_var_sig.to_csv("ATAC_high_var.csv", index=False)
print(f"Saved {len(high_var_sig)} peaks to ATAC_high_var.csv ({len(high_var_sig)/len(filtered_all_ATAC)*100:.2f}% retained)")
# Out:
# Variance cutoff = 10.176 (log10 = 1.008)
# -log10P cutoff  = 5.180
# Saved 75857 peaks to ATAC_high_var.csv (14.80% retained)

# %% [markdown]
# With 14.8% of peaks retained, analyzing the data is easier, faster and cleaner. Even though we have less data, it is more meaningful.

# %%
import matplotlib.pyplot as plt

# Compute per-peak summary metrics
filtered_all_ATAC['mean_signal']   = filtered_all_ATAC[sample_cols].mean(axis=1)
filtered_all_ATAC['median_signal'] = filtered_all_ATAC[sample_cols].median(axis=1)
filtered_all_ATAC['std_signal']    = filtered_all_ATAC[sample_cols].std(axis=1)

import matplotlib.pyplot as plt

# Histogram of per-peak mean
plt.figure(figsize=(6,4))
plt.hist(filtered_all_ATAC['mean_signal'], bins=10000)
plt.xscale('log')
plt.xlabel('Mean accessibility (per peak)')
plt.ylabel('Number of peaks')
plt.title('Distribution of Per-Peak Mean Accessibility')
plt.tight_layout()
plt.show()

# Histogram of per-peak median
plt.figure(figsize=(6,4))
plt.hist(filtered_all_ATAC['median_signal'], bins=10000)
plt.xscale('log')
plt.xlabel('Median accessibility (per peak)')
plt.ylabel('Number of peaks')
plt.title('Distribution of Per-Peak Median Accessibility')
plt.tight_layout()
plt.show()


# Hexbin: Mean vs Variance
plt.figure(figsize=(6,5))
hb1 = plt.hexbin(
    filtered_all_ATAC['mean_signal'],
    filtered_all_ATAC['variance'],
    gridsize=60,
    xscale='log',
    yscale='log',
    mincnt=1
)

# add red diagonal line (y = x)
xmin, xmax = plt.xlim()
plt.plot([xmin, xmax], [xmin, xmax], color='red', linestyle='--', linewidth=1)

plt.colorbar(hb1, label='count')
plt.xlabel('Mean accessibility (per peak, log scale)')
plt.ylabel('Variance (per peak, log scale)')
plt.title('Hexbin: Mean vs Variance')
plt.show()

# Hexbin: Median vs Variance
plt.figure(figsize=(6,5))
hb2 = plt.hexbin(
    filtered_all_ATAC['median_signal'],
    filtered_all_ATAC['variance'],
    gridsize=60,
    xscale='log',
    yscale='log',
    mincnt=1
)

# add red diagonal line (y = x)
xmin, xmax = plt.xlim()
plt.plot([xmin, xmax], [xmin, xmax], color='red', linestyle='--', linewidth=1)

plt.colorbar(hb2, label='count')
plt.xlabel('Median accessibility (per peak, log scale)')
plt.ylabel('Variance (per peak, log scale)')
plt.title('Hexbin: Median vs Variance')
plt.show()

# Hexbin: Std Dev vs Variance
plt.figure(figsize=(6,5))
hb3 = plt.hexbin(
    filtered_all_ATAC['std_signal'],
    filtered_all_ATAC['variance'],
    gridsize=60,
    xscale='log',
    yscale='log',
    mincnt=1
)

# add red diagonal line (y = x)
xmin, xmax = plt.xlim()
plt.plot([xmin, xmax], [xmin, xmax], color='red', linestyle='--', linewidth=1)

plt.colorbar(hb3, label='count')
plt.xlabel('Std. Dev. of accessibility (per peak, log scale)')
plt.ylabel('Variance (per peak, log scale)')
plt.title('Hexbin: Std Dev vs Variance')
plt.show()

# %%
# compute summaries
filtered_all_ATAC['mean_signal']   = filtered_all_ATAC[sample_cols].mean(axis=1)
filtered_all_ATAC['median_signal'] = filtered_all_ATAC[sample_cols].median(axis=1)
filtered_all_ATAC['std_signal']    = filtered_all_ATAC[sample_cols].std(axis=1)

# %%
import numpy as np, matplotlib.pyplot as plt

# add a tiny offset so zeros don’t become –∞
x = np.log10(filtered_all_ATAC['mean_signal']   + 1e-6)
y = np.log10(filtered_all_ATAC['median_signal'] + 1e-6)

plt.figure(figsize=(6,5))
hb = plt.hexbin(x, y, gridsize=60, mincnt=1, cmap='viridis')
plt.colorbar(hb, label='Count of peaks')

# add red diagonal line (y = x)
xmin, xmax = plt.xlim()
plt.plot([xmin, xmax], [xmin, xmax], color='red', linestyle='--', linewidth=1)

plt.xlabel('log10(mean accessibility)')
plt.ylabel('log10(median accessibility)')
plt.title('Hexbin: log10(Mean) vs log10(Median)')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Prepare log‐transformed data (add tiny ε so zeros don’t go to –∞)
eps = 1e-6
x = np.log10(filtered_all_ATAC['mean_signal'] + eps)
y = np.log10(filtered_all_ATAC['std_signal']  + eps)

# Plot hexbin on the log‐transformed axes
plt.figure(figsize=(6,5))
hb = plt.hexbin(
    x, y,
    gridsize=60,
    mincnt=1,
    cmap='viridis'
)

# add red diagonal line (y = x)
xmin, xmax = plt.xlim()
plt.plot([xmin, xmax], [xmin, xmax], color='red', linestyle='--', linewidth=1)
plt.colorbar(hb, label='Count of peaks')

# Label axes and title
plt.xlabel('log10(mean accessibility)')
plt.ylabel('log10(std. dev. of accessibility)')
plt.title('Hexbin: log10(Mean) vs. log10(Std Dev)')

plt.tight_layout()
plt.show()

# %% [markdown]
# These plots were generated as a way of helping us filter out peaks. The chosen metric was MAD cutoffs for low variance and low confidence scores.
